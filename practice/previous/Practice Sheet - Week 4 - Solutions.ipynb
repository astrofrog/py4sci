# %% [markdown]
# Practice Sheet - Week 4 - Solutions
# ===================================
#
# Practice Problem 1
# ------------------

# %%
# Open file
f = open('data.txt', 'r')

# Read and ignore header lines
header1 = f.readline()
header2 = f.readline()
header3 = f.readline()

jmag = {}

# Loop over lines and extract variables of interest
for line in f:
    line = line.strip()
    columns = line.split()
    name = columns[2]
    jmag[name] = float(columns[3])

print jmag['00424455+4116103']
# Out:
# 10.773

# %% [markdown]
# Practice Problem 2
# ------------------

# %%
days = []
temperatures = []

for line in open('munich_temperatures_average.txt', 'r'):
    
    day, temperature = line.strip().split()
    
    # day and temperature are strings so we need to convert them
    # when we append them to the lists
    days.append(float(day))
    temperatures.append(float(temperature))

# The above gives us lists, but easier if we now convert to arrays
days = np.array(days)
temperatures = np.array(temperatures)

plt.plot(days, temperatures)

# %%
plt.plot(days % 1., temperatures, 'k.', alpha=0.3)
