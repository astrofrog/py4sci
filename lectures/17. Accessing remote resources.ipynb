# %% [markdown]
# Accessing Remote Resources
# ==========================
#
# Web pages and data
# ------------------
#
# I have mentioned before how one can access data files on your hard drive, but Python also allows you to access remote data, for example on the internet. The easiest way to do this is to use the built-in [urllib](http://docs.python.org/2/library/urllib.html) module. To start off, you have to open the URL and keep it as a Python object:

# %%
from urllib import urlopen
u = urlopen('http://xkcd.com/353/')

# %% [markdown]
# Note that in Python 3, you should instead use:
#
#     from urllib.request import urlopen
#
# Now, ``u`` will behave similarly to a (read-only) file object. You can read the contents as you would a normal file:

# %%
content = u.read()

# %%
print content[:1000]  # only print the first 1000 characters
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN"
#     "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html version="-//W3C//DTD XHTML 1.1//EN" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en">
# <head>
# <link rel="stylesheet" type="text/css" href="/s/d16ebb.css" title="Default"/>
# <title>xkcd: Python</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>
# <link rel="apple-touch-icon-precomposed" href="/s/d9522a.png" />
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insert

# %% [markdown]
# You can either just use this information directly, or in some cases you might want to write it to a file. Let's download one of the full resolution files for the Ice coverage data from Problem Set 9:

# %%
u2 = urlopen('http://mpia.de/~robitaille/share/ice_data/20060313.npy')

# %%
content = u2.read()

# %% [markdown]
# Now we can open a new (binary) file and download the data to the file.

# %%
f = open('20060313.npy', 'wb')
f.write(content)
f.close()

# %% [markdown]
# Let's now load and plot the data:

# %%
data = np.load('20060313.npy')
plt.figure(figsize=(12,12))
plt.imshow(data, origin='lower')

# %% [markdown]
# APIs
# ----
#
# Imagine that you want to access some data online. In some cases, you will need to download a web page and search through the HTML to extract what you want. For example:

# %%
u = urlopen('http://www.wetteronline.de/wetter/heidelberg')
content = u.read()

# %%
content
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n <title>Wetter Heidelberg - Wetter aktuell und Wettervorhersage - WetterOnline</title>\n <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n <meta name="description" content="Das Wetter in Heidelberg - Wetter aktuell und Wettervorhersage f\xc3\xbcr heute und morgen sowie Wettertrend, Wetterwarnung, Regenradar und mehr von wetteronline.de" />\n <meta name="keywords" content="Wetter Heidelberg, Baden-W\xc3\xbcrttemberg, Deutschland, Wetter, Wetter aktuell, Morgen, \xc3\x9cbermorgen, Wettervorhersage, Wetterprognose, Wettertrend, Regenradar, Wetterwarnung, Unwetter, Regen, Schnee, Wetterfilm, Blitze, wetter, online" />\n <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n <meta http-equiv="content-language" content="de-DE" />\n <meta name="skype_toolbar" content="skype_toolbar_parser_compatible" />\n <meta property="fb:admins" content="100001020190994" />\n <meta property="og:title" content="Wetter Heidelberg - Wetter aktuell und Wettervorhersage - WetterOnline">\n <meta property="og:type" content="article">\n <meta property="og:image" content="http://st.wetteronline.de/img/logo/wetteronline_ball_windows8.png?v=1.0.484">\n <meta property="og:url" content="http://www.wetteronline.de/wetter/heidelberg">\n <meta property="og:description" content="Das Wetter in Heidelberg - Wetter aktuell und Wettervorhersage f\xc3\xbcr heute und morgen sowie Wettertrend, Wetterwarnung, Regenradar und mehr von wetteronline.de">\n <meta property="og:locale" content="de_DE">\n <meta property="og:site_name" content="WetterOnline">\n <meta name="application-name" content="Wetter Heidelberg - Wetter aktuell und Wettervorhersage - WetterOnline"/>\n <meta name="msapplication-TileColor" content="#ffffff"/>\n <meta name="msapplication-TileImage" content="http://st.wetteronline.de/img/logo/wetteronline_ball_windows8.png?v=1.0.484"/>\n <link rel="apple-touch-icon" href="http://st.wetteronline.de/img/logo/apple-touch-icon.png?v=1.0.484" sizes="72x72" />\n <link rel="publisher" href="https://plus.google.com/108164279989314748748/" />\n <link rel="shortcut icon" type="image/x-icon" href="http://st.wetteronline.de/favicon.ico" />\n <link rel="canonical" href="http://www.wetteronline.de/wetter/heidelberg">\n  <link href="http://st.wetteronline.de/css/wetteronline.css?v=1.0.484" rel="stylesheet" media="screen" />\n <link href="http://st.wetteronline.de/css/pc_city_weather.css?v=1.0.484" rel="stylesheet" media="screen" type="text/css" />\n <!--[if lte IE 8]>\n      <link href="http://st.wetteronline.de/css/wetteronline-ie8.css?v=1.0.484" rel="stylesheet" media="screen"/>\n <![endif]-->\n <!--[if lte IE 7]>\n      <link href="http://st.wetteronline.de/css/wetteronline-ie7.css?v=1.0.484" rel="stylesheet" media="screen" />\n <![endif]-->\n <link href="http://st.wetteronline.de/css/print.css?v=1.0.484" rel="stylesheet" media="print" />\n <link href="http://st.wetteronline.de/css/print.css?v=1.0.484" rel="alternate stylesheet" media="screen" title="Druckansicht" />\n <link rel="stylesheet" media="only screen and (max-device-width: 1024px)" href="http://st.wetteronline.de/css/ipad.css?v=1.0.484" />\n\n <link href="http://st.wetteronline.de/css/datepicker.css?v=1.0.484" rel="stylesheet" media="screen" type="text/css"/> \n <script type="text/javascript" src="http://st.wetteronline.de/js/lib/mootools/library-1.4.5-1.4.0.1.js?v=1.0.484"></script>\n <script type="text/javascript" src="http://st.wetteronline.de/js/tt.js?v=1.0.484"></script>\n <script type="text/javascript">\n  if (!WO) var WO = {}; // @namespace\n  WO.version = "1.0.484";\n  WO.system = "";\n </script>\n <script type="text/javascript" src="http://st.wetteronline.de/js/strings.de.js?v=1.0.484"></script>\n <script type="text/javascript">\n  WO.strings.mapsurl = "http://mapsdemo.wetteronline.de/"\n  WO.user = {action : false};\n  WO.cookie = {};\n </script>\n<!-- ((DEBUG_TREE_JS)) -->\n<!-- ((DEBUG_TREE_CSS)) -->\n<!-- ((DEBUG_TREE_INIT)) -->\n <script type ...

# %% [markdown]
# This is not ideal because it is messy, and also slow if all you want are a couple of values. A number of websites now offer an "Application programming interface" (or API) which is basically a way of accessing data is a machine-readable way. Let's take a look at http://openweathermap.org/ for example, which has an API: http://openweathermap.org/API. To access the weather for Heidelberg, you can do:

# %%
u = urlopen('http://api.openweathermap.org/data/2.5/weather?q=Heidelberg,Germany')
content = u.read()

# %%
content
# Out:
# '{"coord":{"lon":8.69,"lat":49.41},"sys":{"message":0.1263,"country":"DE","sunrise":1390201837,"sunset":1390233729},"weather":[{"id":701,"main":"Mist","description":"mist","icon":"50d"}],"base":"cmc stations","main":{"temp":276.55,"humidity":91,"pressure":1001,"temp_min":276.15,"temp_max":277.04},"wind":{"speed":1.96,"deg":320.006},"clouds":{"all":92},"dt":1390207032,"id":2907911,"name":"Heidelberg","cod":200}\n'

# %% [markdown]
# This is much shorter, but still not ideal for reading into Python as-is. The format above is called JSON, and Python includes a library to easily read in this data:

# %%
import json
data = json.loads(content, encoding='ascii')

# %%
data
# Out:
# {u'base': u'cmc stations',
#  u'clouds': {u'all': 92},
#  u'cod': 200,
#  u'coord': {u'lat': 49.41, u'lon': 8.69},
#  u'dt': 1390207032,
#  u'id': 2907911,
#  u'main': {u'humidity': 91,
#   u'pressure': 1001,
#   u'temp': 276.55,
#   u'temp_max': 277.04,
#   u'temp_min': 276.15},
#  u'name': u'Heidelberg',
#  u'sys': {u'country': u'DE',
#   u'message': 0.1263,
#   u'sunrise': 1390201837,
#   u'sunset': 1390233729},
#  u'weather': [{u'description': u'mist',
#    u'icon': u'50d',
#    u'id': 701,
#    u'main': u'Mist'}],
#  u'wind': {u'deg': 320.006, u'speed': 1.96}}

# %% [markdown]
# You should now be able to do:

# %%
data[u'main'][u'temp']
# Out:
# 276.55

# %% [markdown]
# It looks like the temperature is in K!
