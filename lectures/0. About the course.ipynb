# %% [markdown]
# About the course
# ================
#
# About myself
# ------------
#
# My name is [Thomas Robitaille](http://mpia.de/~robitaille/) and I am the leader of a research group at the Max Planck Institut für Astronomie. I carry out research on star formation in the Milky-Way and other galaxies, and I use Python for my daily work. I have developed a number of Python packages for Astronomers, including [APLpy](http://aplpy.github.io), [ATpy](http://atpy.github.io), [Montage-wrapper](http://www.astropy.org/montage-wrapper/), [PyAVM](https://github.com/astrofrog/pyavm). I have also contributed to [Scipy](http://www.scipy.org) and other scientific packages, and am one of the project leaders for [Astropy](http://www.astropy.org), which is a big project to create one main Python package for Astronomy.
#
# ![GLIMPSE](http://mpia.de/~robitaille/glimpse.png)
#
# You can contact me at **robitaille@mpia.de**.
#
# This is the first year that I teach this course, so please let me know if you have feedback/suggestions for improving the course!
#
# Course outline
# --------------
#
# - 15 April - Introduction
# - 22 April - Modules and Functions
# - 29 April - Introduction to Numpy and Matplotlib
# - 6 May - Reading/writing data from files
# - 13 May - More about Numpy and Python variables
# - 27 May - Fitting models to data with Scipy
# - 3 June - Interpolation and integration with Scipy
# - 10 June - Interlude: Version control with Git
# - 17 June - Using the IPython Notebook
# - 1 July - Speeding up Python
# - 8 July - Python as a glue (os module, web access, ...)
# - 15 July - Object-oriented programming
# - 22 July - Advanced topics (Parallel computing in Python, etc.)
#
# Structure
# ---------
#
# The course will be in English.
#
# Lecture/practical session every Monday from 16:15 to 18:00. Format is flexible, but will usually start with a mini-lecture on a new topic every week, followed by time to try/practice what was demonstrated and work on problems. Students can also work on problems at other times during the week, either in the CIP pool, or on their on laptops (see below).
#
# There will be a problem set every week that you should submit solutions to. There will be *no* final exam. An average of 60% in the problem sets will be required to obtain the 2 credits at the end of the course.
#
# Solutions should be submitted individually, *not* in groups. The deadline for solutions to be handed in is **18:00 on Friday of the same week the problem set was given** (so the deadline for Problem Set 1 is 18:00 on Friday 19th April).
#
# The lecture notes will be progressively made available over the semester via the Moodle. The notes are written in the IPython nobebook which you will learn about later in the semester. At the start of each session, I will go over the notebook for that session, but I will not read over everything, so you can go back and look at it in detail after I have gone over it.
#
# You do not learn much programming by simply listening to me or by copying code from other people - the only real way to learn is to **try**! From time to time, I will suggest optional problems for anyone who is interested, but these will not be marked, and are just for practice.
#
# Solutions
# ---------
#
# Solutions should be handed it via [GitHub](http://www.github.com). The first time you go there, you will need to create a free account. Once you are logged in to GitHub:
#
# - go to [Gist](https://gist.github.com/)
# - enter a description (Solution to Problem X)
# - name (use the problem set, exercise number, and ``.py``, so e.g. ``1.1.py`` for the first exercise from the first problem set)
# - paste the code into the box (you can still edit it once it is posted)
# - select 'Python' for the language if not already selected
# - if you need to submit multiple files, you can click on 'Add another file'
# - click 'Create Secret Gist'
# - review, make changes, until you are ready to submit it
# - go to [this form](https://docs.google.com/forms/d/1kIWT0r-U8WZxep35QOVl5XvXuyCZTx--KG024SMbkgA/viewform), enter your name, the problem number, and enter the URL (it will look like ``https://gist.github.com/astrofrog/2a2e8809af2b35b716ee``).
#
# Each problem set is graded out of 10. This is a combination of the following criteria - the problem should:
#
# - run with no errors (if it is unable to run at all, 50% of the points will be deducted for that exercise)
# - produce the correct results
# - be clearly readable, and include comments explaining what is being done
# - remove any unused code!
# - include a header summarizing the problem and if there are any special instructions for running the program. You can use triple quotes to enclose the header information:
#
#         """
#         Program to compute prime numbers
#         Author: Thomas Robitaille
#
#         You can run this program with ``python primes.py``
#         """
#
# There is not always a unique solution to a problem, so it does not matter if your programs do not look the same as somebody else's! What matters most is that you find your own way of doing it.
#
# Laptops
# -------
#
# If you would like to use Python on your laptop, you have several possibilities:
#
# - If you have a linux laptop and are familiar with package managers, most major scientific Python packages are available through these
# - Otherwise, try and install the [Anaconda Python distribution](http://continuum.io/downloads.html)
#
# Come and speak to me after the course (18:00) if you have any questions or need any help getting set up.
